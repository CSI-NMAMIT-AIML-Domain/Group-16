# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df=pd.read_csv('Advertising And Sales.csv')

# %%
df
# Out:
#       ID     TV  Radio  Newspaper  Sales
# 0      1  230.1   37.8       69.2   22.1
# 1      2   44.5   39.3       45.1   10.4
# 2      3   17.2   45.9       69.3    9.3
# 3      4  151.5   41.3       58.5   18.5
# 4      5  180.8   12.8       58.4   12.9
# ..   ...    ...    ...        ...    ...
# 195  196   38.2    3.7       13.8    7.6
# 196  197   94.2    4.9        8.1    9.7
# 197  198  177.0   11.0        6.4   12.8
# 198  199  283.6   42.0       66.2   25.5
# 199  200  232.1    8.1        8.7   14.6
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# ID           0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
import seaborn as sns

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df_sales = pd.read_csv('Advertising And Sales.csv')  # Replace with your file path
top_10 = df_sales.nlargest(10, 'Sales')
# Bar plot for TV advertising budget vs Sales
plt.figure(figsize=(8, 6))
sns.barplot(x='TV', y='Sales', data=top_10)
plt.title('Sales vs TV Advertising Budget')
plt.show()

# Bar plot for Radio advertising budget vs Sales
plt.figure(figsize=(8, 6))
sns.barplot(x='Radio', y='Sales', data=top_10)
plt.title('Sales vs Radio Advertising Budget')
plt.show()

# Bar plot for Newspaper advertising budget vs Sales
plt.figure(figsize=(8, 6))
sns.barplot(x='Newspaper', y='Sales', data=top_10)
plt.title('Sales vs Newspaper Advertising Budget')
plt.show()

# %%
plt.figure(figsize=(10, 5)) 
plt.subplot(1, 3, 1)
sns.scatterplot(x='TV', y='Sales', data= df)
plt.title('Scatter Plot of TV budget vs Sales')

# Scatter plot for second pair
plt.subplot(1, 3, 2)
sns.scatterplot(x='Radio', y='Sales', data= df)
plt.title('Scatter Plot of Radio budget vs Sales')
plt.subplot(1, 3, 3)
sns.scatterplot(x='Newspaper', y='Sales', data= df)
plt.title('Scatter Plot of Newspaper budget vs Sales')
# Show the plots
plt.tight_layout()
plt.show()
